# %% [markdown]
# # ***Importing the Required Libraries***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
plt.style.use('Solarize_Light2')

# %% [markdown]
# # ***Importing the dataset***

# %%
df = pd.read_csv('../input/dogecoin-historical-data/DOGE-USD.csv')

# %% [markdown]
# # ***Exploring and Cleaning the Dataset***

# %%
df.shape
# Out:
# (2164, 7)

# %%
df.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume
# 0  2017-11-09  0.001207  0.001415  0.001181  0.001415   0.001415  6259550
# 1  2017-11-10  0.001421  0.001431  0.001125  0.001163   0.001163  4246520
# 2  2017-11-11  0.001146  0.001257  0.001141  0.001201   0.001201  2231080
# 3  2017-11-12  0.001189  0.001210  0.001002  0.001038   0.001038  3288960
# 4  2017-11-13  0.001046  0.001212  0.001019  0.001211   0.001211  2481270
# 5  2017-11-14  0.001201  0.001239  0.001131  0.001184   0.001184  2660340
# 6  2017-11-15  0.001189  0.001351  0.001179  0.001339   0.001339  2840180
# 7  2017-11-16  0.001348  0.001424  0.001286  0.001390   0.001390  3423010
# 8  2017-11-17  0.001381  0.001394  0.001274  0.001313   0.001313  2787480
# 9  2017-11-18  0.001308  0.001385  0.001254  0.001373   0.001373  1648260

# %%
df.tail(10)
# Out:
#             Date      Open      High       Low     Close  Adj Close     Volume
# 2154  2023-10-03  0.062054  0.062269  0.061228  0.061386   0.061386  156615776
# 2155  2023-10-04  0.061389  0.061561  0.060458  0.061488   0.061488  141610437
# 2156  2023-10-05  0.061486  0.061607  0.060839  0.060923   0.060923  114148166
# 2157  2023-10-06  0.060920  0.061555  0.060821  0.061426   0.061426  109783884
# 2158  2023-10-07  0.061425  0.061669  0.061129  0.061455   0.061455   97620505
# 2159  2023-10-08  0.061456  0.061611  0.060876  0.061008   0.061008   92483679
# 2160  2023-10-09  0.061010  0.061030  0.058260  0.058779   0.058779  241183528
# 2161  2023-10-10  0.058779  0.059204  0.058608  0.059025   0.059025  123311323
# 2162  2023-10-11  0.059041  0.059454  0.057813  0.058470   0.058470  146066511
# 2163  2023-10-12  0.058470  0.058488  0.057500  0.057771   0.057771  120287472

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2164 entries, 0 to 2163
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2164 non-null   object
#  1   Open       2164 non-null   float64
#  2   High       2164 non-null   float64
#  3   Low        2164 non-null   float64
#  4   Close      2164 non-null   float64
#  5   Adj Close  2164 non-null   float64
#  6   Volume     2164 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 118.5+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2164.000000  2164.000000  2164.000000  2164.000000  2164.000000
# mean      0.062426     0.065708     0.059261     0.062462     0.062462
# std       0.091750     0.098803     0.084913     0.091797     0.091797
# min       0.001046     0.001210     0.001002     0.001038     0.001038
# 25%       0.002656     0.002722     0.002597     0.002657     0.002657
# 50%       0.005992     0.006431     0.005719     0.006014     0.006014
# 75%       0.080191     0.082483     0.077584     0.080190     0.080190
# max       0.687801     0.737567     0.608168     0.684777     0.684777
#
#              Volume
# count  2.164000e+03
# mean   9.358082e+08
# std    3.246002e+09
# min    1.431720e+06
# 25%    3.645901e+07
# 50%    1.645669e+08
# 75%    6.216320e+08
# max    6.941068e+10

# %% [markdown]
# # ***Checking for Null Values***

# %%
df.isnull().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %% [markdown]
# # ***Checking for Duplicate Values***

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # ***Volume***

# %%
plt.figure(figsize=(20, 8))
df.groupby('Date')['Volume'].median().plot(linewidth=2.5, color='blue')
plt.xlabel('Date', fontsize=12)
plt.ylabel('Volume', fontsize=12)
plt.title("Date vs Volume", fontsize=16)  
plt.grid(True, linestyle='--', alpha=0.5)  
plt.tight_layout()

# %%
df1 = df.tail(285)
plt.figure(figsize=(20,8))
df1.groupby('Date')['Volume'].mean().plot(linewidth = 1.5, marker ='o')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title("Date vs Volume of 2023")
# Out:
# Text(0.5, 1.0, 'Date vs Volume of 2023')

# %% [markdown]
# # ***Opening Price***

# %%
plt.figure(figsize=(20,7))
df.groupby('Date')['Open'].mean().plot(linewidth = 2.5, color = 'blue')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title("Date vs Open")
# Out:
# Text(0.5, 1.0, 'Date vs Open')

# %%
plt.figure(figsize=(20,7))
df1.groupby('Date')['Open'].mean().plot(linewidth = 2.5, color = 'blue')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title("Date vs Open of 2023")
# Out:
# Text(0.5, 1.0, 'Date vs Open of 2023')

# %% [markdown]
# # ***High Price***

# %%
plt.figure(figsize=(20,8))
df.groupby('Date')['High'].mean().plot(linewidth = 2.5, color = 'blue')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title("Date vs High")
# Out:
# Text(0.5, 1.0, 'Date vs High')

# %%
plt.figure(figsize=(20,8))
df1.groupby('Date')['High'].mean().plot(linewidth = 2.5, color = 'blue')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title("Date vs High of 2023")
# Out:
# Text(0.5, 1.0, 'Date vs High of 2023')

# %% [markdown]
# # ***Low Price***

# %%
plt.figure(figsize=(20,8))
df.groupby('Date')['Low'].mean().plot(linewidth = 2.5, color = 'blue')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title("Date vs Low")
# Out:
# Text(0.5, 1.0, 'Date vs Low')

# %%
plt.figure(figsize=(20,8))
df1.groupby('Date')['Low'].mean().plot(linewidth = 2.5, color = 'blue')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title("Date vs Low of 2023")
# Out:
# Text(0.5, 1.0, 'Date vs Low of 2023')

# %% [markdown]
# # ***Close Price***

# %%
plt.figure(figsize=(20,8))
df.groupby('Date')['Close'].mean().plot(linewidth = 2.5, color = 'blue')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title("Date vs Close")
# Out:
# Text(0.5, 1.0, 'Date vs Close')

# %%
plt.figure(figsize=(20,8))
df1.groupby('Date')['Close'].mean().plot(linewidth = 2.5, color = 'blue')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title("Date vs Close of 2023")
# Out:
# Text(0.5, 1.0, 'Date vs Close of 2023')

# %% [markdown]
# # ***Adjustment Price***

# %%
plt.figure(figsize=(25,8))
df.groupby('Date')['Adj Close'].mean().plot(linewidth = 3.5, color = 'blue')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title("Date vs Adj Close")
# Out:
# Text(0.5, 1.0, 'Date vs Adj Close')

# %%
plt.figure(figsize=(25,8))
df1.groupby('Date')['Adj Close'].mean().plot(linewidth = 3.5, color = 'blue')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title("Date vs Adj Close of 2023")
# Out:
# Text(0.5, 1.0, 'Date vs Adj Close of 2023')

# %% [markdown]
# # ***Co-Relation between Features***

# %%
new_df =pd.read_csv('../input/dogecoin-historical-data/DOGE-USD.csv', usecols = ['Open','High','Low','Close','Volume']).fillna(method='ffill')

# %%
plt.figure(figsize = (8,6))
sns.heatmap(new_df.corr() , cmap = 'hot', annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # ***Train-Test Split***

# %%
x = new_df.drop('High', axis=1)
y = new_df['High']

print('Shape of X = ', x.shape)
print('Shape of y = ', y.shape)
# Out:
# Shape of X =  (2164, 4)
# Shape of y =  (2164,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print('Shape of x_train = ', x_train.shape)
print('Shape of y_train = ', y_train.shape)
print('Shape of x_test = ', x_test.shape)
print('Shape of y_test = ', y_test.shape)
# Out:
# Shape of x_train =  (1731, 4)
# Shape of y_train =  (1731,)
# Shape of x_test =  (433, 4)
# Shape of y_test =  (433,)

# %% [markdown]
# # ***Random Forest Regression***

# %%
from sklearn import metrics

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=500, criterion='friedman_mse',random_state=0)
regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(criterion='friedman_mse', n_estimators=500,
#                       random_state=0)

# %%
y_pred = regressor.predict(x_test)

# %%
print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'Residual Sum of Squares(MSE): {metrics.mean_squared_error(y_test, y_pred)}')
print(f'R2-Score: {metrics.r2_score(y_test, y_pred)}')
score_rf = round(metrics.r2_score(y_test, y_pred) * 100, 3)
# Out:
# Mean Absolute Error(MAE): 0.0014569327436489202
# Residual Sum of Squares(MSE): 2.2126455755268812e-05
# R2-Score: 0.9972865229815048

# %%
ds = pd.DataFrame()
ds['High']=y_test

ds['Prediction']=y_pred
ds.head(10)
# Out:
#           High  Prediction
# 2076  0.072752    0.071727
# 1601  0.148559    0.146156
# 1431  0.248663    0.246580
# 1134  0.004113    0.003939
# 1512  0.175771    0.173003
# 1786  0.062040    0.062120
# 478   0.002013    0.002037
# 1001  0.003636    0.003616
# 2026  0.073917    0.073757
# 1745  0.070961    0.071287

# %%
sns.heatmap(ds.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # ***Linear Regression***

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
regr = LinearRegression()
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regr.predict(x_test)
print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'Residual Sum of Squares(MSE): {metrics.mean_squared_error(y_test, y_pred)}')
print(f'R2-Score: {metrics.r2_score(y_test, y_pred)}')
score_lr = round(metrics.r2_score(y_test, y_pred) * 100, 3)
# Out:
# Mean Absolute Error(MAE): 0.0010736767288653307
# Residual Sum of Squares(MSE): 9.24674989384619e-06
# R2-Score: 0.9988660251957998

# %%
y_pred = regressor.predict(x_test)
ds = pd.DataFrame()
ds['High']=y_test
ds['Prediction']=y_pred
ds.head(10)
# Out:
#           High  Prediction
# 2076  0.072752    0.071727
# 1601  0.148559    0.146156
# 1431  0.248663    0.246580
# 1134  0.004113    0.003939
# 1512  0.175771    0.173003
# 1786  0.062040    0.062120
# 478   0.002013    0.002037
# 1001  0.003636    0.003616
# 2026  0.073917    0.073757
# 1745  0.070961    0.071287

# %%
sns.heatmap(ds.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # ***Decision Tree Regressor***

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dtr.predict(x_test)
print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'Residual Sum of Squares(MSE): {metrics.mean_squared_error(y_test, y_pred)}')
print(f'R2-Score: {metrics.r2_score(y_test, y_pred)}')
score_dt = round(metrics.r2_score(y_test, y_pred) * 100, 3)
# Out:
# Mean Absolute Error(MAE): 0.00172008545034642
# Residual Sum of Squares(MSE): 2.6051473609699746e-05
# R2-Score: 0.9968051785735715

# %%
y_pred = regressor.predict(x_test)
ds = pd.DataFrame()
ds['High']=y_test
ds['Prediction']=y_pred
ds.head(10)
# Out:
#           High  Prediction
# 2076  0.072752    0.071727
# 1601  0.148559    0.146156
# 1431  0.248663    0.246580
# 1134  0.004113    0.003939
# 1512  0.175771    0.173003
# 1786  0.062040    0.062120
# 478   0.002013    0.002037
# 1001  0.003636    0.003616
# 2026  0.073917    0.073757
# 1745  0.070961    0.071287

# %%
sns.heatmap(ds.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # ***XGBoost Regressor***

# %%
from xgboost.sklearn import XGBRegressor
xgb = XGBRegressor()
xgb.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = xgb.predict(x_test)
print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'Residual Sum of Squares(MSE): {metrics.mean_squared_error(y_test, y_pred)}')
print(f'R2-Score: {metrics.r2_score(y_test, y_pred)}')
score_xg = round(metrics.r2_score(y_test, y_pred) * 100, 3)
# Out:
# Mean Absolute Error(MAE): 0.0017524456785760177
# Residual Sum of Squares(MSE): 3.361636754918059e-05
# R2-Score: 0.9958774581072132

# %%
y_pred = xgb.predict(x_test)
ds = pd.DataFrame()
ds['High']=y_test
ds['Prediction']=y_pred
ds.head(10)
# Out:
#           High  Prediction
# 2076  0.072752    0.071400
# 1601  0.148559    0.146599
# 1431  0.248663    0.248138
# 1134  0.004113    0.003969
# 1512  0.175771    0.172867
# 1786  0.062040    0.062584
# 478   0.002013    0.002101
# 1001  0.003636    0.003969
# 2026  0.073917    0.073797
# 1745  0.070961    0.070811

# %%
sns.heatmap(ds.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # ***Lasso Regression***

# %%
from sklearn import linear_model
lasso = linear_model.Lasso(alpha=0.1)
lasso.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_pred = lasso.predict(x_test)
print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'Residual Sum of Squares(MSE): {metrics.mean_squared_error(y_test, y_pred)}')
print(f'R2-Score: {metrics.r2_score(y_test, y_pred)}')
score_lar = round(metrics.r2_score(y_test, y_pred) * 100, 3)
# Out:
# Mean Absolute Error(MAE): 0.05606173560655679
# Residual Sum of Squares(MSE): 0.005717583643065055
# R2-Score: 0.29882435811769736

# %%
y_pred = lasso.predict(x_test)
ds = pd.DataFrame()
ds['High']=y_test
ds['Prediction']=y_pred
ds.head(10)
# Out:
#           High  Prediction
# 2076  0.072752    0.057438
# 1601  0.148559    0.066704
# 1431  0.248663    0.076126
# 1134  0.004113    0.051996
# 1512  0.175771    0.059953
# 1786  0.062040    0.055659
# 478   0.002013    0.049096
# 1001  0.003636    0.049947
# 2026  0.073917    0.052330
# 1745  0.070961    0.058798

# %%
sns.heatmap(ds.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # ***Ridge Regression***

# %%
from sklearn import linear_model
ridge = linear_model.Ridge(alpha=0.1)
ridge.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
y_pred = ridge.predict(x_test)
print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'Residual Sum of Squares(MSE): {metrics.mean_squared_error(y_test, y_pred)}')
print(f'R2-Score: {metrics.r2_score(y_test, y_pred)}')
score_rr = round(metrics.r2_score(y_test, y_pred) * 100, 3)
# Out:
# Mean Absolute Error(MAE): 0.0014591230397179144
# Residual Sum of Squares(MSE): 1.3577083788747962e-05
# R2-Score: 0.9983349748714193

# %%
y_pred = ridge.predict(x_test)
ds = pd.DataFrame()
ds['High']=y_test
ds['Prediction']=y_pred
ds.head(10)
# Out:
#           High  Prediction
# 2076  0.072752    0.072054
# 1601  0.148559    0.148800
# 1431  0.248663    0.248228
# 1134  0.004113    0.003576
# 1512  0.175771    0.174420
# 1786  0.062040    0.063018
# 478   0.002013    0.001582
# 1001  0.003636    0.003276
# 2026  0.073917    0.074806
# 1745  0.070961    0.071145

# %%
sns.heatmap(ds.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # ***Gradient Boosting Regressor***

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor()
gb.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = gb.predict(x_test)
print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'Residual Sum of Squares(MSE): {metrics.mean_squared_error(y_test, y_pred)}')
print(f'R2-Score: {metrics.r2_score(y_test, y_pred)}')
score_gb = round(metrics.r2_score(y_test, y_pred) * 100, 3)
# Out:
# Mean Absolute Error(MAE): 0.001676063291883412
# Residual Sum of Squares(MSE): 2.0926856158941962e-05
# R2-Score: 0.9974336358301251

# %%
y_pred = gb.predict(x_test)
ds = pd.DataFrame()
ds['High']=y_test
ds['Prediction']=y_pred
ds.head(10)
# Out:
#           High  Prediction
# 2076  0.072752    0.072739
# 1601  0.148559    0.148890
# 1431  0.248663    0.245081
# 1134  0.004113    0.003790
# 1512  0.175771    0.172325
# 1786  0.062040    0.062119
# 478   0.002013    0.002220
# 1001  0.003636    0.003670
# 2026  0.073917    0.073654
# 1745  0.070961    0.071263

# %%
sns.heatmap(ds.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # ***Output Final Scores***

# %%
scores = [score_lr, score_dt, score_rf, score_lar, score_rr, score_xg, score_gb]
algorithms = ["Linear Regression", "Decision Tree Regressor", "Random Forest Regressor", "Lasso Regression", "Ridge Regression", "XGBoost Regressor", "Gradient Boosting Regressor"]

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Linear Regression is: 99.887 %
# The accuracy score achieved using Decision Tree Regressor is: 99.681 %
# The accuracy score achieved using Random Forest Regressor is: 99.729 %
# The accuracy score achieved using Lasso Regression is: 29.882 %
# The accuracy score achieved using Ridge Regression is: 99.833 %
# The accuracy score achieved using XGBoost Regressor is: 99.588 %
# The accuracy score achieved using Gradient Boosting Regressor is: 99.743 %

# %% [markdown]
# # ***Plotting the Results***

# %%
sns.set(rc={'figure.figsize':(20,10)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

sns.barplot(x = algorithms,y = scores)
# Out:
# <Axes: xlabel='Algorithms', ylabel='Accuracy score'>
